# %% [markdown]
# # FILTRADO DE DATOS

# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({
    'edad': [10, 22, 13, 21, 12, 11, 17],
    'seccion': ['A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'ciudad': ['Cordoba', 'Orizaba', 'Fortin', 'Cordoba', 'Orizaba', 'Cordoba', 'Orizaba'],
    'genero': ['M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'color_favorito': ['rojo', np.NAN, 'amarillo', np.NAN, 'azul', 'verde', np.NAN]
})

# %%
data
# Out:
#    edad seccion   ciudad genero color_favorito
# 0    10       A  Cordoba      M           rojo
# 1    22       B  Orizaba      F            NaN
# 2    13       C   Fortin      F       amarillo
# 3    21       B  Cordoba      M            NaN
# 4    12       B  Orizaba      M           azul
# 5    11       A  Cordoba      M          verde
# 6    17       A  Orizaba      F            NaN

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   edad            7 non-null      int64
#  1   seccion         7 non-null      object
#  2   ciudad          7 non-null      object
#  3   genero          7 non-null      object
#  4   color_favorito  4 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 408.0+ bytes

# %%
data.ciudad
# Out:
# 0    Cordoba
# 1    Orizaba
# 2     Fortin
# 3    Cordoba
# 4    Orizaba
# 5    Cordoba
# 6    Orizaba
# Name: ciudad, dtype: object

# %%
data.ciudad[2]
# Out:
# 'Fortin'

# %%
data.loc[data.edad >= 15]
# Out:
#    edad seccion   ciudad genero color_favorito
# 1    22       B  Orizaba      F            NaN
# 3    21       B  Cordoba      M            NaN
# 6    17       A  Orizaba      F            NaN

# %%
data.loc[(data.edad >= 15) & (data.genero == 'M')]
# Out:
#    edad seccion   ciudad genero color_favorito
# 3    21       B  Cordoba      M            NaN

# %%
data.loc[(data.edad >= 12), ['seccion']] = 'I'

# %%
data
# Out:
#    edad seccion   ciudad genero color_favorito
# 0    10       A  Cordoba      M           rojo
# 1    22       I  Orizaba      F            NaN
# 2    13       I   Fortin      F       amarillo
# 3    21       I  Cordoba      M            NaN
# 4    12       I  Orizaba      M           azul
# 5    11       A  Cordoba      M          verde
# 6    17       I  Orizaba      F            NaN

# %%
data.loc[(data.edad >= 12), ['seccion', 'ciudad']] = ['S', 'Xalapa']
data
# Out:
#    edad seccion   ciudad genero color_favorito
# 0    10       A  Cordoba      M           rojo
# 1    22       S   Xalapa      F            NaN
# 2    13       S   Xalapa      F       amarillo
# 3    21       S   Xalapa      M            NaN
# 4    12       S   Xalapa      M           azul
# 5    11       A  Cordoba      M          verde
# 6    17       S   Xalapa      F            NaN

# %%
data.iloc[[0, 2]]
# Out:
#    edad seccion   ciudad genero color_favorito
# 0    10       A  Cordoba      M           rojo
# 2    13       S   Xalapa      F       amarillo

# %%
data.iloc[[0, 2], [1, 3]]
# Out:
#   seccion genero
# 0       A      M
# 2       S      F

# %%
data.iloc[[0]]
# Out:
#    edad seccion   ciudad genero color_favorito
# 0    10       A  Cordoba      M           rojo

# %%
data.iloc[:,[0]]
# Out:
#    edad
# 0    10
# 1    22
# 2    13
# 3    21
# 4    12
# 5    11
# 6    17

# %% [markdown]
# # CABECERAS

# %%
data = data[['edad', 'seccion', 'ciudad', 'genero']]
data
# Out:
#    edad seccion   ciudad genero
# 0    10       A  Cordoba      M
# 1    22       S   Xalapa      F
# 2    13       S   Xalapa      F
# 3    21       S   Xalapa      M
# 4    12       S   Xalapa      M
# 5    11       A  Cordoba      M
# 6    17       S   Xalapa      F

# %%
cabecera = ['age', 'section', 'city', 'gender']
data.columns = cabecera
data
# Out:
#    age section     city gender
# 0   10       A  Cordoba      M
# 1   22       S   Xalapa      F
# 2   13       S   Xalapa      F
# 3   21       S   Xalapa      M
# 4   12       S   Xalapa      M
# 5   11       A  Cordoba      M
# 6   17       S   Xalapa      F

# %% [markdown]
# ## Mostrar la columna de generos = F

# %%
data.loc[data.gender == 'F'][['gender']]
# Out:
#   gender
# 1      F
# 2      F
# 6      F

# %%
data.loc[(data.age <= 20) & (data.gender == 'F')][['age', 'gender']]
# Out:
#    age gender
# 2   13      F
# 6   17      F

# %%
data.loc[(data.age <= 20) & (data.gender == 'F')]
# Out:
#    age section    city gender
# 2   13       S  Xalapa      F
# 6   17       S  Xalapa      F

# %%
data.sort_values(['gender', 'city'])
# Out:
#    age section     city gender
# 1   22       S   Xalapa      F
# 2   13       S   Xalapa      F
# 6   17       S   Xalapa      F
# 0   10       A  Cordoba      M
# 5   11       A  Cordoba      M
# 3   21       S   Xalapa      M
# 4   12       S   Xalapa      M

# %%
data.sort_values(['age'], ascending = [False])
# Out:
#    age section     city gender
# 1   22       S   Xalapa      F
# 3   21       S   Xalapa      M
# 6   17       S   Xalapa      F
# 2   13       S   Xalapa      F
# 4   12       S   Xalapa      M
# 5   11       A  Cordoba      M
# 0   10       A  Cordoba      M
